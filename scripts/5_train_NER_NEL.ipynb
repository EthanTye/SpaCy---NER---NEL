# %%
#Training for the NER component done via command line and config file.
# In the directory containing the base_config.cfg file run command:
# python -m spacy train base_config.cfg --output ./base_model
#
# with GPU: python -m spacy train base_config.cfg --output ./base_model --gpu-id 0.

# %%
import torch
import spacy
from spacy.scorer import Scorer

# %%
spacy.prefer_gpu()
nlp = spacy.load('../base_model/model-last')

# %%
print(torch.cuda.memory_reserved(0))
torch.cuda.get_device_properties(0).total_memory
# Out:
# 1088421888
# 8589606912

# %% [markdown]
# ## Training the entity linker

# %%
import json

# %%
with open('../data/mp_train_el.json',"r", encoding = "utf8") as f:
    train = json.load(f)

with open('../data/mp_val_el.json',"r", encoding = "utf8") as f:
    val = json.load(f)

# %%
# reformatting labelled data into appropriate format for training the NEL component
def data_creator(data):
    dataset = []
    for line in data:
        try:
            if line != []:
                example = line
                text = line[0]
                for entities in line[1]["links"]:
                    qid = entities[3]
                    links_dict = {qid: 1.0}
                    offset = (entities[0], entities[1])
                    entities = [(entities[0], entities[1], entities[2])]
                dataset.append((text,{'links': {offset: links_dict}, 'entities': entities}))
        except:
            pass
    return(dataset)

# %%
train_data = data_creator(train)
val_data = data_creator(val)

# %%
# adding tagger and parser components to the pipeline. We can use pretrained versions from the en_core_web_trf transformers like our NER and NEL component
source = spacy.load('en_core_web_trf')
tagger = nlp.add_pipe('tagger', before = 'ner', source = source)
parser = nlp.add_pipe('parser', before = 'ner', source = source)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5092/4045866080.py in <module>
#       1 # adding tagger and parser components to the pipeline. We can use pretrained versions from the en_core_web_trf transformers like our NER and NEL component
#       2 source = spacy.load('en_core_web_trf')
# ----> 3 tagger = nlp.add_pipe('tagger', before = 'ner', source = source)
#       4 parser = nlp.add_pipe('parser', before = 'ner', source = source)
#       5 attr_r = nlp.add_pipe('attribute_ruler', before = 'ner', source = source)
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     774         name = name if name is not None else factory_name
#     775         if name in self.component_names:
# --> 776             raise ValueError(Errors.E007.format(name=name, opts=self.component_names))
#     777         if source is not None:
#     778             # We're loading the component from a model. After loading the
#
# ValueError: [E007] 'tagger' already exists in pipeline. Existing names: ['transformer', 'tagger', 'parser', 'ner']

# %%
attr_r = nlp.add_pipe('attribute_ruler', before = 'ner', source = source)

# %%
from spacy.training import Example

# %%
train_data
# Out:
# [('MINDEF Cyber Work Learn Scheme.',
#   {'links': {(0, 6): {'Ministry of Defence ': 1.0}},
#    'entities': [(0, 6, 'ORG')]}),
#  ("if WP supporters adhered to safe distancing rules and were able to be more organised, it would have been super impressive and boosted WP's image even further haha",
#   {'links': {(134, 136): {"Workers' Party": 1.0}},
#    'entities': [(134, 136, 'ORG')]}),
#  ('Aunty on MRT insulting Singaporeans and complaining about everything under the Sun',
#   {'links': {(79, 82): {'Sun Xueling': 1.0}},
#    'entities': [(79, 82, 's_pol')]}),
#  ("There was only 1 warzone match my ping was at 160+... at least it's better than before.  Hope it gets better for u too.",
#   {'links': {(46, 49): {'The Straits Times': 1.0}},
#    'entities': [(46, 49, 'ORG')]}),
#  ('Government monitoring hospital capacity closely as Covid-19 cases remain high: Ong Ye Kung',
#   {'links': {(79, 90): {'Ong Ye Kung': 1.0}},
#    'entities': [(79, 90, 's_pol')]}),
#  ('Straits Times: Parliament: All bus services in the red because of Covid-19, only 11 profitable before, says Ong Ye Kung',
#   {'links': {(108, 119): {'Ong Ye Kung': 1.0}},
#    'entities': [(108, 119, 's_pol')]}),
#  ("😭 Low Thia Khiang made me cried! One of his reasons on becoming a MP with Workers' Party Singapore!",
#   {'links': {(74, 88): {"Workers' Party": 1.0}},
#    'entities': [(74, 88, 'ORG')]}),
#  ('Sylvia Interview Debunked',
#   {'links': {(0, 6): {'Sylvia Lim': 1.0}}, 'entities': [(0, 6, 's_pol')]}),
#  ("I wonder what thoughts were going through Dennis's mind, being on the committee",
#   {'links': {(42, 48): {'Dennis Tan': 1.0}}, 'entities': [(42, 48, 's_pol')]}),
#  ('Not true. Some, like CCS have sparkling reviews from his military guys. Straight talking, down to earth, always caring for his soldiers. \n\nAs in all things, there are black sheep in every profession.',
#   {'links': {(21, 24): {'Chan Chun Sing': 1.0}},
#    'entities': [(21, 24, 's_pol')]}),
#  ("He's probably implying that if you're in pap it automatically means you don't care about the people and those who care about people should join opposition because that's what opposition believes in unlike pap. \n\nMy response: There are arrogant snobs in PAP, that's undeniable. But I'm pretty sure there are people in pap who genuinely care for the people (I can't think of any examples but feel free to cite any if there are)\n\nMy interpretation might be wrong idk",
#   {'links': {(253, 256): {"People's Action Party": 1.0}},
#    'entities': [(253, 256, 'ORG')]}),
#  ("'Streamlining' of safe management measures will start later, to be rolled out at one go instead of in phases: MOH",
#   {'links': {(110, 113): {'Ministry of Health': 1.0}},
#    'entities': [(110, 113, 'ORG')]}),
#  ('Electoral Boundaries Review Committee not appointed yet: Chan Chun Sing',
#   {'links': {(57, 71): {'Chan Chun Sing': 1.0}},
#    'entities': [(57, 71, 's_pol')]}),
#  ('Dear MOH...',
#   {'links': {(5, 8): {'Ministry of Health': 1.0}},
#    'entities': [(5, 8, 'ORG')]}),
#  ('Anyone received the job application form from MOH?',
#   {'links': {(46, 49): {'Ministry of Health': 1.0}},
#    'entities': [(46, 49, 'ORG')]}),
#  ('CNA : Are we spending too much on weddings?',
#   {'links': {(0, 3): {'CNA': 1.0}}, 'entities': [(0, 3, 'ORG')]}),
#  ('PAP is coming..',
#   {'links': {(0, 3): {"People's Action Party": 1.0}},
#    'entities': [(0, 3, 'ORG')]}),
#  ('What are some "sickness" that you regretted "geng-ing" in NS?',
#   {'links': {(58, 60): {'National Service': 1.0}},
#    'entities': [(58, 60, 'ORG')]}),
#  ('CNA commits to enhanced coverage of climate change',
#   {'links': {(0, 3): {'CNA': 1.0}}, 'entities': [(0, 3, 'ORG')]}),
#  ('Oh dear… Massive prompts to you and your family for self-quarantining though. I really hope MOH will pull through in your case. \n\nCall the 1800 MOH hotline. Don’t bother leaving your number, they will only call back days later. I still haven’t receive mine yet. \n\nEventually someone will pick up, and be sure to explain your case fully. \n\nPraying for the best of well-being for you and your close ones.',
#   {'links': {(144, 147): {'Ministry of Health': 1.0}},
#    'entities': [(144, 147, 'ORG')]}),
#  ('Mr Huang showed ST the text message he received from his daughter at 11.50am and a video of students running in the school grounds. She texted him about five minutes later, saying the situation was under control. But he said he drove from his home in Pasir Ris to the school anyway.\n\n&#x200B;\n\njust wanna say the dedication (Pasir Ris to Boon Lay) for parents to put their child in top schools. \\*thumbs up\\*',
#   {'links': {(16, 18): {'The Straits Times': 1.0}},
#    'entities': [(16, 18, 'ORG')]}),
#  ('I agree. Too much democracy can honestly hinder progress, although I feel we are at a stage where more oppositions can be beneficial to keep PAP in check. Although I feel that only WP and maybe PSP will function well in that regard.',
#   {'links': {(181, 183): {"Workers' Party": 1.0}},
#    'entities': [(181, 183, 'ORG')]}),
#  ('Fk it, just come out and say “we’ll never fully open again, you’ll have to wear masks indefinitely, still quarantine when travelling even if vaxxed, TraceForever to prove your vax status, still limit on group sizes, no nightlife”, better then a false sense of seeing light at the end of an ever-increasing tunnel.',
#   {'links': {(149, 161): {'Trace Together': 1.0}},
#    'entities': [(149, 161, 'ORG')]}),
#  ('Yeah true. PR wise is a win-win. \n\nKnowing what ‘they’ think and speak of you, ‘lousy school’, ‘illiterate’ and maybe unintelligent are pretty hurtful but politics are for the ‘thick skin’ and thicker the better it seems. \n\nJust like the old school/NS days, never let them see you cry!',
#   {'links': {(249, 251): {'National Service': 1.0}},
#    'entities': [(249, 251, 'ORG')]}),
#  ('Wuhan virus: It is wrong to profiteer from increased demand for face masks, says Chan Chun Sing',
#   {'links': {(81, 95): {'Chan Chun Sing': 1.0}},
#    'entities': [(81, 95, 's_pol')]}),
#  ('Attempts to delegitimise police, enforcement agencies increasing: Shanmugam',
#   {'links': {(66, 75): {'K Shanmugam': 1.0}},
#    'entities': [(66, 75, 's_pol')]}),
#  ('Something the PAP will never get from their voters',
#   {'links': {(14, 17): {"People's Action Party": 1.0}},
#    'entities': [(14, 17, 'ORG')]}),
#  ('sure my friends have gotten rejected from higher education like jcs because they are trans and they are sure MOE is responsible for it but do you think its worth their time and effort to destroy their future by protesting against something they will not win? please be pragmatic and think logically',
#   {'links': {(109, 112): {'Ministry of Education': 1.0}},
#    'entities': [(109, 112, 'ORG')]}),
#  ('But that would also throw a negative optic to WP in the light of not being sympathetic to a SA survivor. And people who care about these kinda issues are also mostly in WP’s voter base too.\n\nYou can already imagine all the SJWs and liberals who would slam and cancel PS and WP for asking her to fess up at a time when she needed support the most, and for cruelly revealing her SA when she had not meant for it to be disclosed.\n\nLike I said, no winning for PS and WP in all of these.',
#   {'links': {(463, 465): {"Workers' Party": 1.0}},
#    'entities': [(463, 465, 'ORG')]}),
#  ('Lim Tean wants PM Lee and Ministers to reduce their salaries to ZERO',
#   {'links': {(15, 21): {'Lee Hsien Loong': 1.0}},
#    'entities': [(15, 21, 's_pol')]}),
#  ('Well hopefully the swing voters decide to judge both the PAP and WP',
#   {'links': {(65, 67): {"Workers' Party": 1.0}},
#    'entities': [(65, 67, 'ORG')]}),
#  ('If you watch his entire speech, the flub was literally for the last ten seconds. You are repeatedly bringing up the worst ten seconds in a man’s career. Heng Swee Keat remains a humble man with a brilliant brain, and I would still vote for him.',
#   {'links': {(153, 167): {'Heng Swee Keat': 1.0}},
#    'entities': [(153, 167, 's_pol')]}),
#  ("Sympathy, disappointment, resignation &amp; WP's future: Local political commentators react to Raeesah Khan's admissions",
#   {'links': {(95, 107): {'Raeesah Khan': 1.0}},
#    'entities': [(95, 107, 's_pol')]}),
#  ('What is their point though? Are they trying to glorify NS life? It looks like one of those hipster hostels.',
#   {'links': {(55, 57): {'National Service': 1.0}},
#    'entities': [(55, 57, 'ORG')]}),
#  ('Gonna steal ur TT token to set you up',
#   {'links': {(15, 17): {'Trace Together': 1.0}},
#    'entities': [(15, 17, 'ORG')]}),
#  ('I highly recommend using the TraceTogether app. It has a safe entry check in QR code reader inbuilt and has made my life so much more convenient',
#   {'links': {(29, 42): {'Trace Together': 1.0}},
#    'entities': [(29, 42, 'ORG')]}),
#  ('Won’t be surprised because do you really think the old school or established companies watch NOC and gives two shits about who Sylvia Chan is?',
#   {'links': {(127, 133): {'Sylvia Lim': 1.0}},
#    'entities': [(127, 133, 's_pol')]}),
#  ('\\#2 and #4 often happens together though. I saw both NSP & PAP doing walkabouts during the past couple weekends, so idk about you but in my area they have been walking the ground.',
#   {'links': {(59, 62): {"People's Action Party": 1.0}},
#    'entities': [(59, 62, 'ORG')]}),
#  ('You are the blind one here if you think /r/Singapore is blind to the shit that the PAP does.',
#   {'links': {(83, 86): {"People's Action Party": 1.0}},
#    'entities': [(83, 86, 'ORG')]}),
#  ('One does not need to be a social liberal to recognise the urgent need for political liberalisation in Singapore. \n\nSocial conservatives would do well to remember that illiberalism can easily be weaponised to silence our voices if the PAP ever finds it to its political advantage.',
#   {'links': {(234, 237): {"People's Action Party": 1.0}},
#    'entities': [(234, 237, 'ORG')]}),
#  ('>On one occasion, she had confided in Sylvia about getting diagnosed with depression. Instead of sympathy, Michelle felt that she was met with apathy. She said she was simply told to “eat more medicine”.\n\nSorry out of NOC, but this reminds me of my current colleague told me to call IMH while actually he was the one caused me to go depression on works last year..',
#   {'links': {(38, 44): {'Sylvia Lim': 1.0}}, 'entities': [(38, 44, 's_pol')]}),
#  ('PM Lee Speaks publicly about Ivan Lim',
#   {'links': {(0, 6): {'Lee Hsien Loong': 1.0}},
#    'entities': [(0, 6, 's_pol')]}),
#  ('Maid asked to care for 104-year-old man and share bed with him breaks down, MOM investigating',
#   {'links': {(76, 79): {'Ministry of Manpower': 1.0}},
#    'entities': [(76, 79, 'ORG')]}),
#  ('I think the point the person is making is that is she did not state that her remarks were "derogatory", and for the PAP to infer it as such is not appropriate',
#   {'links': {(116, 119): {"People's Action Party": 1.0}},
#    'entities': [(116, 119, 'ORG')]}),
#  ("I'd imagine that PAP will harp on this for the next 50 years and keep demanding WP to step down or something lmao",
#   {'links': {(80, 82): {"Workers' Party": 1.0}},
#    'entities': [(80, 82, 'ORG')]}),
#  ('Because perhaps no news sites will share this, thank you for keeping this here and let’s spread the word of Dr Jamus Lim :D',
#   {'links': {(111, 120): {'Jamus Lim': 1.0}},
#    'entities': [(111, 120, 's_pol')]}),
#  ("Let's see when MSM will report this, cos as far as I know, they only reported it when MOM released the initial statement",
#   {'links': {(86, 89): {'Ministry of Manpower': 1.0}},
#    'entities': [(86, 89, 'ORG')]}),
#  ('You know whats sad, PAP in my honest view really played the propaganda tool on the older generation. My late grandfather was deathly afraid when my dad said he wanted to try and vote for the opposition some time back. He was afraid that the ISD would haul him into the night and never be heard again.  \n\n\nThis is a guy who survived WW2 as someone who took risk helping the resistance and hated Japan to the core. And he is afraid of his own government.',
#   {'links': {(20, 23): {"People's Action Party": 1.0}},
#    'entities': [(20, 23, 'ORG')]}),
#  ("you wont get 10 years for assaulting someone..maybe if he did that to LHL..but he'll probably get strokes",
#   {'links': {(70, 73): {'Lee Hsien Loong': 1.0}},
#    'entities': [(70, 73, 's_pol')]}),
#  ('Time for mandatory National Service for females?',
#   {'links': {(19, 35): {'National Service': 1.0}},
#    'entities': [(19, 35, 'ORG')]}),
#  ('> situation classified as " very bad" \n\nYou mean when we\'re rank 158 it isn\'t very bad?',
#   {'links': {(65, 68): {'The Straits Times': 1.0}},
#    'entities': [(65, 68, 'ORG')]}),
#  ('To be a little more accurate, and citing the ST article you linked:\n\n> The shopping mall component of the development from B1 to Level 2, called The Star Vista, is owned and managed by CapitaLand Mall Asia. \n\nSo the church is only responsible for the Star Performing Arts Centre.  \n\n> The Star Performing Arts Centre takes up the third to 11th floors. Rock Productions purchased the land on a 60-year lease for about $189 million. \n\nThis is still very extensive floor area though.\n\n&#x200B;',
#   {'links': {(45, 47): {'The Straits Times': 1.0}},
#    'entities': [(45, 47, 'ORG')]}),
#  ('Discrimination even when you sacrifice for your Country! Why is an ACL tear by Officer more valuable to MINDEF than when same injury is sustained by Specialist/Recruit, when both got injured during service? Is this another policy like how our Para-Olympic Medallist are treated?',
#   {'links': {(104, 110): {'Ministry of Defence ': 1.0}},
#    'entities': [(104, 110, 'ORG')]}),
#  ("I made Mothership's table more complete.",
#   {'links': {(7, 17): {'Mothership': 1.0}}, 'entities': [(7, 17, 'ORG')]}),
#  ("Yup that's how the public service is run in essence - NS lite. Might be because of the background of those in management...",
#   {'links': {(54, 56): {'National Service': 1.0}},
#    'entities': [(54, 56, 'ORG')]}),
#  ('Ban on PMDs at void decks, common areas to start Sep 1: PAP town councils',
#   {'links': {(56, 59): {"People's Action Party": 1.0}},
#    'entities': [(56, 59, 'ORG')]}),
#  ('Wake up singapore page. This page is just toxic. I don’t see anything wrong with the ex minister using tiktok to reach out to his younger audience. This page has frequently attacked the PAP ministers with no apparent reason. They always contradict themselves too. What a disgusting page.',
#   {'links': {(186, 189): {"People's Action Party": 1.0}},
#    'entities': [(186, 189, 'ORG')]}),
#  ('As I said man, if US has it, Singapore is going to have one and Singaporeans are acting so surprised about it. \n\nGovernment spying on me through TT? Get over yourselves, its called mass surveillance.',
#   {'links': {(145, 147): {'Trace Together': 1.0}},
#    'entities': [(145, 147, 'ORG')]}),
#  ("MP Louis Ng: Being naked in your own home doesn't kill your neighbour, but second-hand smoke could",
#   {'links': {(3, 11): {'Louis Ng': 1.0}}, 'entities': [(3, 11, 's_pol')]}),
#  ('Can someone with ST full access paste the text here? Curious about this',
#   {'links': {(17, 19): {'The Straits Times': 1.0}},
#    'entities': [(17, 19, 'ORG')]}),
#  ('Despite different governance systems, US, China share some goals and challenges: Ong Ye Kung',
#   {'links': {(81, 92): {'Ong Ye Kung': 1.0}},
#    'entities': [(81, 92, 's_pol')]}),
#  ('Coronavirus could take years to run its course, world must brace itself: PM Lee',
#   {'links': {(73, 79): {'Lee Hsien Loong': 1.0}},
#    'entities': [(73, 79, 's_pol')]}),
#  ('Lawrence Wong and Gan Kim Yong to resign from MMTF Lawrence Wong and Gan Kim Yong to resign from MMTF',
#   {'links': {(69, 81): {'Gan Kim Yong': 1.0}},
#    'entities': [(69, 81, 's_pol')]}),
#  ("Not exactly, I'm no fan of WP. More so just really disgusted by Raeesah's behaviour, lack of loyalty, and falsely zealous personality. Can't trust politicians to put Singapore and Singaporeans first.",
#   {'links': {(64, 71): {'Raeesah Khan': 1.0}},
#    'entities': [(64, 71, 's_pol')]}),
#  ('lo-fi LHL beats to keep calm/fight covid-19 to',
#   {'links': {(6, 9): {'Lee Hsien Loong': 1.0}},
#    'entities': [(6, 9, 's_pol')]}),
#  ("unfortunately no. check my reddit icon 😂but I didn't know there was a NS deduction for taxes too!",
#   {'links': {(70, 72): {'National Service': 1.0}},
#    'entities': [(70, 72, 'ORG')]}),
#  ('Don’t worry government give 3k\n\nAnd take back through other means\n\n3k means shit. PAP with all the worthless paper generals',
#   {'links': {(82, 85): {"People's Action Party": 1.0}},
#    'entities': [(82, 85, 'ORG')]}),
#  ('The point isn’t about how fucked up he is as a person. The point here is that even PAP doesn’t have a foolproof approach when it comes to screening their candidates.',
#   {'links': {(83, 86): {"People's Action Party": 1.0}},
#    'entities': [(83, 86, 'ORG')]}),
#  ('>Rather, I think one should look at timing, where VB found out in October 2020 that TT was used to trace crimes, but only in January 2021 did the govt clarify, which is also 3 months.\n\nThe time VB found out TT was used is not the same as the time the government is aware that TT can be used. Which actually increase the timeline',
#   {'links': {(276, 278): {'Trace Together': 1.0}},
#    'entities': [(276, 278, 'ORG')]}),
#  ('This is not a moot point as QR code does not allow full data transfer of whatever is stored inside the TT token. \n\nWhat i am saying is that TT token’s data may not be as “safe” as people assume just because there is no ability to transfer data via wifi or 3G networks.\n\nWhat you were saying in your previous comment is that TT Token is likely to be safer than the phone app as data transfer of stored data on the token is unlikely due to lack of wifi/3G.',
#   {'links': {(324, 326): {'Trace Together': 1.0}},
#    'entities': [(324, 326, 'ORG')]}),
#  ("Thanks for your story.   When I saw Sim Lim Tower, I braced for what I thought for sure was another horror rip-off story.  But yours is the one with the surprise ending.  Please help promo this uncle's shop.",
#   {'links': {(36, 39): {'Sim Ann': 1.0}}, 'entities': [(36, 39, 's_pol')]}),
#  ('All you have done is changing the topic or go way out of the point.\n\nWe are talking about: TT = track criminals\n\nAnd u came up with shit like “who decides the law?”, “government lied”, “so what is a crime?”.\n\nAll of which doesn’t even have to do with TT. If u wanna continue, fine. But if you don’t say anything that has to do with the topic, I’m not gonna bother anymore.',
#   {'links': {(251, 253): {'Trace Together': 1.0}},
#    'entities': [(251, 253, 'ORG')]}),
#  ("'Aghast and disappointed’: Koh Poh Koon slams doctors for spreading myths, untruths in open letter on Covid-19 vaccine",
#   {'links': {(27, 39): {'Koh Poh Koon': 1.0}},
#    'entities': [(27, 39, 's_pol')]}),
#  ("There wouldn't be any whataboutism if PAP is competent to solve the tracetogether murder case saga, Murali's viral video and Ivan Lim's investigation. All of these are swept under the rug and you guys only wanna look at the other side? Well why don't PAP supporters make posts about these since it's already a year after some of these cases already? And finally get down to the truth behind. I really want to know who are the culprits that hurt Murali's family right before election, those evil people.",
#   {'links': {(251, 254): {"People's Action Party": 1.0}},
#    'entities': [(251, 254, 'ORG')]}),
#  ("Ah yes! Finally someone who actually read WP's manifesto.",
#   {'links': {(42, 44): {"Workers' Party": 1.0}},
#    'entities': [(42, 44, 'ORG')]}),
#  ('Mandatory swab tests for stallholders after Redhill market visited by COVID-19 case: MP Melvin Yong',
#   {'links': {(88, 99): {'Melvin Yong': 1.0}},
#    'entities': [(88, 99, 's_pol')]}),
#  ('Not to forget OYK put up a stellar performance. Anyone who goes up against him tomorrow will need to minimally match that.',
#   {'links': {(14, 17): {'Ong Ye Kung': 1.0}},
#    'entities': [(14, 17, 's_pol')]}),
#  ('Not possible to enforce and stop smoking at home windows: Amy Khor',
#   {'links': {(58, 66): {'Amy Khor': 1.0}}, 'entities': [(58, 66, 's_pol')]}),
#  ('Govt review on CPF’s Retirement Sum Scheme payout rules to be completed by end 2019: MOM',
#   {'links': {(85, 88): {'Ministry of Manpower': 1.0}},
#    'entities': [(85, 88, 'ORG')]}),
#  ("Can we all talk abt how small LHL's eyes are? They are smaller than the width of eraser dust",
#   {'links': {(30, 33): {'Lee Hsien Loong': 1.0}},
#    'entities': [(30, 33, 's_pol')]}),
#  ('Got my PES status for NS recently, when can I expect to be enlisted?',
#   {'links': {(22, 24): {'National Service': 1.0}},
#    'entities': [(22, 24, 'ORG')]}),
#  ('Ben Leong - "In Defence of MOE and HBL"',
#   {'links': {(27, 30): {'Ministry of Education': 1.0}},
#    'entities': [(27, 30, 'ORG')]}),
#  ('LHL ready to dedicate his heart',
#   {'links': {(0, 3): {'Lee Hsien Loong': 1.0}},
#    'entities': [(0, 3, 's_pol')]}),
#  ('he is more hard carry than Tharman.',
#   {'links': {(27, 34): {'Tharman Shanmugaratnam': 1.0}},
#    'entities': [(27, 34, 's_pol')]}),
#  ('>NS will also tell you safety begins with YOU\n\nthat not how the hierarchy inside works man. MINDEF is just not a conducive environment for it',
#   {'links': {(92, 98): {'Ministry of Defence ': 1.0}},
#    'entities': [(92, 98, 'ORG')]}),
#  ("Workers' Party NCMP Daniel Goh steps down from party posts, will not contest next GE",
#   {'links': {(0, 14): {"Workers' Party": 1.0}}, 'entities': [(0, 14, 'ORG')]}),
#  ('Traditional degree route not a must before going out to work: Lawrence Wong',
#   {'links': {(62, 75): {'Lawrence Wong': 1.0}},
#    'entities': [(62, 75, 's_pol')]}),
#  ('No easing of restrictions for now amid spike in COVID-19 cases: Lawrence Wong',
#   {'links': {(64, 77): {'Lawrence Wong': 1.0}},
#    'entities': [(64, 77, 's_pol')]}),
#  ('"MOE aware that gaps need plugging."',
#   {'links': {(1, 4): {'Ministry of Education': 1.0}},
#    'entities': [(1, 4, 'ORG')]}),
#  ("Still haven't answer my question. Vivian can mock on LMW's education and I can't comment on his financial literacy?",
#   {'links': {(53, 56): {'Leong Mun Wai': 1.0}},
#    'entities': [(53, 56, 's_pol')]}),
#  ('Yes paradise for the elites and the crazy rich Asians!!!!\nCovered in the embrace of PAP and Kong hee fatt choy billion dollar harvest!!!!shabalalalala!!!\n\nIf u really want to know what is paradise,I suggest u go to Australia.',
#   {'links': {(84, 87): {"People's Action Party": 1.0}},
#    'entities': [(84, 87, 'ORG')]}),
#  ('Faraday bag. Interesting. How does this one work ? Is TT RFID or Bluetooth ?',
#   {'links': {(54, 56): {'Trace Together': 1.0}},
#    'entities': [(54, 56, 'ORG')]}),
#  ('If this shit blows up it’ll be good for Pritam to call for by election in Aljunied and SK as form of apology. \n\nThis will put it to bed on the punishment WP should be taking for this whole saga. Either they win or lose the by election, the next election result will be better.',
#   {'links': {(154, 156): {"Workers' Party": 1.0}},
#    'entities': [(154, 156, 'ORG')]}),
#  ("MOM's behaviour in this saga was puzzling to say the least. Either they are maliciously trying to muddy the waters by using their status to discredit Jade Rasif, or they are so disorganised that they can't get their ducks in a row before coming up with a statement. I can't figure out which is worse or whether both are true.",
#   {'links': {(0, 3): {'Ministry of Manpower': 1.0}},
#    'entities': [(0, 3, 'ORG')]}),
#  ("Time to update: Former DJ Jade Rasif's account of maid with COVID-19 'accurate', says MOM.",
#   {'links': {(86, 89): {'Ministry of Manpower': 1.0}},
#    'entities': [(86, 89, 'ORG')]}),
#  ('Sun Halo @ ECP',
#   {'links': {(0, 3): {'Sun Xueling': 1.0}}, 'entities': [(0, 3, 's_pol')]}),
#  ('MOH: The B1617 variant prevalent in South Asia is not just a Singapore problem. The WHO has deemed it a variant of global concern.',
#   {'links': {(0, 3): {'Ministry of Health': 1.0}},
#    'entities': [(0, 3, 'ORG')]}),
#  ('S’pore trying very hard to avoid start-stops in Covid-19 measures: Lawrence Wong',
#   {'links': {(67, 80): {'Lawrence Wong': 1.0}},
#    'entities': [(67, 80, 's_pol')]}),
#  ('I feel bad for Pritam Singh.',
#   {'links': {(15, 27): {'Pritam Singh': 1.0}},
#    'entities': [(15, 27, 's_pol')]}),
#  ('I thought WP IBs only operated in the online space. Apparently, you can use this sort of whataboutism in a COP hearing as well. \n\nThis is why AHTC will occur again, under the WP aegis. Because, despite all the dishonest behaviour, despite all the coverups that Pritam has engaged in, all it takes is a soundbite to swing people emotionally.',
#   {'links': {(261, 267): {'Pritam Singh': 1.0}},
#    'entities': [(261, 267, 's_pol')]}),
#  ('Anonymous Hacker Collective Takes Credit for Cyberattacks Against Russian Government',
#   {'links': {(74, 84): {'Government': 1.0}}, 'entities': [(74, 84, 'ORG')]}),
#  ("You're complaining of doing meaningless office work during NS instead of going outfield??? What type of entitled whiner are you??",
#   {'links': {(59, 61): {'National Service': 1.0}},
#    'entities': [(59, 61, 'ORG')]}),
#  ('Totally misguided to think Civil Service can counteract bad government- PM Lee',
#   {'links': {(72, 78): {'Lee Hsien Loong': 1.0}},
#    'entities': [(72, 78, 's_pol')]}),
#  ('CNA’s nightly news has always been my favourite proramme',
#   {'links': {(0, 3): {'CNA': 1.0}}, 'entities': [(0, 3, 'ORG')]}),
#  ("Changes in Covid-19 updates to align with current strategy of 'living with Covid-19': MOH",
#   {'links': {(86, 89): {'Ministry of Health': 1.0}},
#    'entities': [(86, 89, 'ORG')]}),
#  ('>re outrage from singaporeans. If that happened today you can bet the public would take umbrage\n\nLMAO if that newspaper happened today, more would ends up voting oppositions and SPH would be the one getting owned like how those who tried to sabotage raeesah khan during GE 2020 ends up getting rekt when WP managed to sengkang grc.',
#   {'links': {(304, 306): {"Workers' Party": 1.0}},
#    'entities': [(304, 306, 'ORG')]}),
#  ('Huge respect to Jade for exposing MOM.',
#   {'links': {(34, 37): {'Ministry of Manpower': 1.0}},
#    'entities': [(34, 37, 'ORG')]}),
#  ("Don't worry, pretty sure most ppl (I hope) know how horrible and shitty the SAF org is.\n\n>sacred cow and untouchable\n\nYea. Fucking piece of trash org. Bloody disgrace of a military\n\n> So many boys have died in NS due to the negligence and malicious intent of the officers and sergeants and yet we still get dead NSFs popping up from time to time for the same reasons.\n\nSo sad, so true. Spitting straight fax",
#   {'links': {(210, 212): {'National Service': 1.0}},
#    'entities': [(210, 212, 'ORG')]}),
#  ("New Workers' Party CEC members take on roles as office bearers",
#   {'links': {(4, 18): {"Workers' Party": 1.0}}, 'entities': [(4, 18, 'ORG')]}),
#  ("Mr Pritam Singh supports Alfian Sa’at - People's Action Party",
#   {'links': {(40, 61): {"People's Action Party": 1.0}},
#    'entities': [(40, 61, 'ORG')]}),
#  ('Beware of fake SGH memo circulating that falsely states that PM Lee has tested positive for COVID-19',
#   {'links': {(61, 67): {'Lee Hsien Loong': 1.0}},
#    'entities': [(61, 67, 's_pol')]}),
#  ("COVID-19: PM Lee calls for unity, resilience to face 'crisis of a generation'",
#   {'links': {(10, 16): {'Lee Hsien Loong': 1.0}},
#    'entities': [(10, 16, 's_pol')]}),
#  ("Hello PAP IB, can't you see this is just the beginning? \n\nFirst it was for contact tracing.\n\nNext for criminal investigation.\n\nNext my data and prediction on my next movement in.",
#   {'links': {(6, 9): {"People's Action Party": 1.0}},
#    'entities': [(6, 9, 'ORG')]}),
#  ("Correct. Also, let's be honest, WP on paper has the best slate of candidates (while the other parties may have 1 or 2 influential key figures).",
#   {'links': {(32, 34): {"Workers' Party": 1.0}},
#    'entities': [(32, 34, 'ORG')]}),
#  ('With Aunties like these do we really need to do National Service?',
#   {'links': {(48, 64): {'National Service': 1.0}},
#    'entities': [(48, 64, 'ORG')]}),
#  (' \n\n*I’m like TT, Just like TT*',
#   {'links': {(27, 29): {'Trace Together': 1.0}},
#    'entities': [(27, 29, 'ORG')]}),
#  ("I think it was in the 2010 election(?) where basically the news of Michael Palmer's (PAP dude) affair came out around election time. Surprise surprise, PAP lost. But the next election round, they got it back",
#   {'links': {(152, 155): {"People's Action Party": 1.0}},
#    'entities': [(152, 155, 'ORG')]}),
#  ('I think anyone with some logic will draw a parallel with TT.',
#   {'links': {(57, 59): {'Trace Together': 1.0}},
#    'entities': [(57, 59, 'ORG')]}),
#  ("MOM 'recommends' employers of transferred maids to share cost of stay-home notice, COVID-19 tests",
#   {'links': {(0, 3): {'Ministry of Manpower': 1.0}},
#    'entities': [(0, 3, 'ORG')]}),
#  ('Uhhh one thing ah, Jamus said it’s uncle poor uncle now has the whole of Singapore thinking he’s an auntie twitch bad hair day. Oops',
#   {'links': {(19, 24): {'Jamus Lim': 1.0}}, 'entities': [(19, 24, 's_pol')]}),
#  ('I hope your sentiments will remain the same if the culprit today is a PAP MP rather than a WP MP.',
#   {'links': {(91, 93): {"Workers' Party": 1.0}},
#    'entities': [(91, 93, 'ORG')]}),
#  ('Meta-relevance.\n\nIt is ironic that people are complaining about the situation in r/SG, when the same sh\\*t, if not worse, is being carried out by the PAP themselves.',
#   {'links': {(150, 153): {"People's Action Party": 1.0}},
#    'entities': [(150, 153, 'ORG')]}),
#  ('Can share tips for PAP vs RP at AMK GRC? No opposition gona move in here. \n\nImo RP should get a vote for doing their job of engaging LHL to walk the ground and spend resources on his GRC, and not go kaypoh at other GRCs. Imagine walkover, wah out of sight out of mind sia (I meant for non-LHL wards at AMK. Like who even is my MP, they just changed new one)',
#   {'links': {(289, 292): {'Lee Hsien Loong': 1.0}},
#    'entities': [(289, 292, 's_pol')]}),
#  ('also if she doesnt wanna pay us our salary then yeah shes gonna get reported to MOM.',
#   {'links': {(80, 83): {'Ministry of Manpower': 1.0}},
#    'entities': [(80, 83, 'ORG')]}),
#  ("Singapore won't reach COVID herd immunity: Lawrence Wong",
#   {'links': {(43, 56): {'Lawrence Wong': 1.0}},
#    'entities': [(43, 56, 's_pol')]}),
#  ('Sinovac vaccine has 2-year shelf life, still being assessed for use in Singapore: MOH official',
#   {'links': {(82, 85): {'Ministry of Health': 1.0}},
#    'entities': [(82, 85, 'ORG')]}),
#  ('WP and PAP contrast, am I the only one seeing this?',
#   {'links': {(7, 10): {"People's Action Party": 1.0}},
#    'entities': [(7, 10, 'ORG')]}),
#  ('Not like the newer PAP ministers are much better.',
#   {'links': {(19, 22): {"People's Action Party": 1.0}},
#    'entities': [(19, 22, 'ORG')]}),
#  ('A Report by CNA on the Olympics Went Viral After Unintentionally Bypassing Censorship',
#   {'links': {(12, 15): {'CNA': 1.0}}, 'entities': [(12, 15, 'ORG')]}),
#  ('GUYS NEXT GE CAN WE TREND MORE HASHTAGS SO CNA CAN PUT IT UP #cockleswarmed #jamusoppa #simpforseah',
#   {'links': {(43, 46): {'CNA': 1.0}}, 'entities': [(43, 46, 'ORG')]}),
#  ('You are assuming the government cares in this case.\n\nThey don\'t, and they never will.\n\nWe\'ve had a shit ton of "international pressure" on various issues and the few times the PAP budged, it was to ensure that THEY got a good deal more than anything.',
#   {'links': {(176, 179): {"People's Action Party": 1.0}},
#    'entities': [(176, 179, 'ORG')]}),
#  ('MOE to expand full subject-based banding pilot to 90 schools by 2023',
#   {'links': {(0, 3): {'Ministry of Education': 1.0}},
#    'entities': [(0, 3, 'ORG')]}),
#  ("Attendance at Victoria Junior College 'very normal' despite coronavirus situation: Ong Ye Kung",
#   {'links': {(83, 94): {'Ong Ye Kung': 1.0}},
#    'entities': [(83, 94, 's_pol')]}),
#  ("So happy WP won Sengkang and kept Hougang/Aljunied, it's a big middle finger to PAP lmfao, PAP thought they could win through gutter politics but their plan backfired big time HAH",
#   {'links': {(91, 94): {"People's Action Party": 1.0}},
#    'entities': [(91, 94, 'ORG')]}),
#  ("Don't know, you can call MOH",
#   {'links': {(25, 28): {'Ministry of Health': 1.0}},
#    'entities': [(25, 28, 'ORG')]}),
#  ("CNA: NUS student who trespassed into hostel rooms to steal women's lingerie gets jail",
#   {'links': {(0, 3): {'CNA': 1.0}}, 'entities': [(0, 3, 'ORG')]}),
#  ("It's just my honest opinion. Despite most more vocal sentiments online, past election data has shown that PAP or HSK still wins almost overwhelmimgly despite minor faux pas. Going with that line of thought, it's clear that PAP winning in EC will be more natural, rather than an anomaly. Oppo winning will be the anomaly, based on what past election shows. No need to read minds or what",
#   {'links': {(287, 291): {'Opposition': 1.0}},
#    'entities': [(287, 291, 'ORG')]}),
#  ("WP should already be calling her that LOL she's a fking burden to any organisation la",
#   {'links': {(0, 2): {"Workers' Party": 1.0}}, 'entities': [(0, 2, 'ORG')]}),
#  ("Remember when people were shitting on that DJ for blasting MOH or whoever that was handling the case for her helper?\n\nWe're seeing this happen daily now, complete turmoil and health care being overrun.",
#   {'links': {(59, 62): {'Ministry of Health': 1.0}},
#    'entities': [(59, 62, 'ORG')]}),
#  ('53 of 65 confirmed imported Omicron COVID-19 cases arrived in Singapore through VTLs: MOH',
#   {'links': {(86, 89): {'Ministry of Health': 1.0}},
#    'entities': [(86, 89, 'ORG')]}),
#  ('Heng, i am not living in East Coast. Given that speech, seems like the PAP team has 0 plan for my Constituency.',
#   {'links': {(71, 74): {"People's Action Party": 1.0}},
#    'entities': [(71, 74, 'ORG')]}),
#  ('Thoughts on Josephine Teo?',
#   {'links': {(12, 25): {'Josephine Teo': 1.0}},
#    'entities': [(12, 25, 's_pol')]}),
#  ('TraceTogether is way better IMO.',
#   {'links': {(0, 13): {'Trace Together': 1.0}}, 'entities': [(0, 13, 'ORG')]}),
#  ("So don't make them be the same. Desmond is desmond, Ivan is Ivan. Condemn one, bring up the other, the party as a whole? They should have checked the background, not just promoting elites.",
#   {'links': {(32, 39): {'Desmond Tan': 1.0}},
#    'entities': [(32, 39, 's_pol')]}),
#  ("Workers' Party lying about hawker centre cleaning: Govt",
#   {'links': {(0, 14): {"Workers' Party": 1.0}}, 'entities': [(0, 14, 'ORG')]}),
#  ('Heng Swee Keat smoobypost',
#   {'links': {(0, 14): {'Heng Swee Keat': 1.0}},
#    'entities': [(0, 14, 's_pol')]}),
#  ('200 have found full-time jobs while undergoing SGUnited traineeships, attachments: MOM',
#   {'links': {(83, 86): {'Ministry of Manpower': 1.0}},
#    'entities': [(83, 86, 'ORG')]}),
#  ("PAP's 'divisive approach is polarising Singapore: Pritam",
#   {'links': {(50, 56): {'Pritam Singh': 1.0}},
#    'entities': [(50, 56, 's_pol')]}),
#  ('I read on singaporelegal that the type of detainment is also decided by MSF minister after court deems the punishment? Did I get that right?\n\nFor minor committing grave offences:\n"the court may sentence your child to be detained for a period within the sentencing guidelines of that particular offence, at a place and on conditions as the Minister for Social and Family Development may decide."',
#   {'links': {(72, 75): {'Ministry of Social and Family Development': 1.0}},
#    'entities': [(72, 75, 'ORG')]}),
#  ('The Straits Times - Childfree: Four women on why they don’t want kids | Facebook',
#   {'links': {(0, 17): {'The Straits Times': 1.0}},
#    'entities': [(0, 17, 'ORG')]}),
#  ("I played it during my NS when we can't use phone but have nothing else to do LOL",
#   {'links': {(22, 24): {'National Service': 1.0}},
#    'entities': [(22, 24, 'ORG')]}),
#  ('Anonymous Instagram account in NOC saga gets pro bono law representation : Mothership',
#   {'links': {(75, 85): {'Mothership': 1.0}}, 'entities': [(75, 85, 'ORG')]}),
#  ('PepeLaugh :point_right: PAP  \nPepeLaugh :point_right: PAP  \nPepeLaugh :point_right: PAP',
#   {'links': {(84, 87): {"People's Action Party": 1.0}},
#    'entities': [(84, 87, 'ORG')]}),
#  ('The only good thing that came out of RK being in WP',
#   {'links': {(49, 51): {"Workers' Party": 1.0}},
#    'entities': [(49, 51, 'ORG')]}),
#  ("To be fair unless you are publishing or sharing stuff that are untrue like LHL helped Najib launder money in the 1mdb scandal, you won't get sued. If you feel you have been wronged by the courts, you are always free to go to the court of public opinion and ask for crowdfund to save your legal fees. \n\nBut once you are dead, you are dead and can never publish anything ever again",
#   {'links': {(75, 78): {'Lee Hsien Loong': 1.0}},
#    'entities': [(75, 78, 's_pol')]}),
#  ('Bilateral agreements have not jeopardised employment opportunities for Singaporeans: Heng Swee Keat',
#   {'links': {(85, 99): {'Heng Swee Keat': 1.0}},
#    'entities': [(85, 99, 's_pol')]}),
#  ('School dropout just received NS registration letter',
#   {'links': {(29, 31): {'National Service': 1.0}},
#    'entities': [(29, 31, 'ORG')]}),
#  ('At least you know that the PAP ranks their candidates appropriately :D',
#   {'links': {(27, 30): {"People's Action Party": 1.0}},
#    'entities': [(27, 30, 'ORG')]}),
#  ('Raeesah Khan admits to lying about accompanying rape victim to police station, apologises for allegations',
#   {'links': {(0, 12): {'Raeesah Khan': 1.0}}, 'entities': [(0, 12, 's_pol')]}),
#  ('PAP being made fun of for dropping Ivan, WP lauded for sticking with RK. Look where that landed us.',
#   {'links': {(41, 43): {"Workers' Party": 1.0}},
#    'entities': [(41, 43, 'ORG')]}),
#  ('Aiyah, nothing will happen one lah. SAF is a sacred cow and untouchable. At the most they will apologize and move on until the next poor dude comes along. So many boys have died in NS due to the negligence and malicious intent of the officers and sergeants and yet we still get dead NSFs popping up from time to time for the same reasons. If anything, this dude should be thankful he didnt go home in a casket.\n\nGo ahead and downvote me',
#   {'links': {(181, 183): {'National Service': 1.0}},
#    'entities': [(181, 183, 'ORG')]}),
#  ('Singapore Democratic Party urges PM Lee to think very carefully',
#   {'links': {(33, 39): {'Lee Hsien Loong': 1.0}},
#    'entities': [(33, 39, 's_pol')]}),
#  ('Ignore the downvotes, you’re absolutely right. \n\nIdiocy tends to flood this subreddit the moment daddy Pritam is being scrutinized lmao.',
#   {'links': {(103, 109): {'Pritam Singh': 1.0}},
#    'entities': [(103, 109, 's_pol')]}),
#  ('Them cheering this GE does not mean they will cheer next GE. Their cheer is a show of support for the current trajectory of the WP. Where do you see that they state they will do so in the future, even if they become a disgusting party?',
#   {'links': {(128, 130): {"Workers' Party": 1.0}},
#    'entities': [(128, 130, 'ORG')]}),
#  ("Do you singaporeans feel that the election cmg next Friday is fair honestly where PAP air time is close to 15mins long or longer ? How about the other parties with minimum 3mins ? I'm only 17 but this is honestly really unfair or unequal ,Singapore being equal with this kind of inequality seems bs",
#   {'links': {(82, 85): {"People's Action Party": 1.0}},
#    'entities': [(82, 85, 'ORG')]}),
#  ('How the government controls SPH (and other newspaper outlets in Singapore).',
#   {'links': {(28, 31): {'The Straits Times': 1.0}},
#    'entities': [(28, 31, 'ORG')]}),
#  ("Everyone hates NS\n\nThose who are forced to conscript hates it\n\nThose who signed on because they couldn't make it elsewhere / were enticed by the salary and iron rice bowl (private degree officers making 5k + when they're still a few years away from 30), hates it\n\nBasically the army is filled with 90% toxicity and people who can't do shit properly. The other 10% are still OK.",
#   {'links': {(15, 17): {'National Service': 1.0}},
#    'entities': [(15, 17, 'ORG')]}),
#  ("No, I have a strong feeling it will be very different this time. After LKY's death, more people are willing to vote for opposition too...plus the whole Raeesah Khan issue has blown up reaaaaally big. There is hope this year",
#   {'links': {(152, 164): {'Raeesah Khan': 1.0}},
#    'entities': [(152, 164, 's_pol')]}),
#  ('Quarantine and SHN must be replaced to revive aviation: Ong Ye Kung',
#   {'links': {(56, 67): {'Ong Ye Kung': 1.0}},
#    'entities': [(56, 67, 's_pol')]}),
#  ('Deliverymen, cabbies &amp; other essential workers can eat at void decks, park benches, or in their vehicles: MOH',
#   {'links': {(110, 113): {'Ministry of Health': 1.0}},
#    'entities': [(110, 113, 'ORG')]}),
#  ('Raeesah Khan shouldn’t have shared ‘untruths’ in Parliament: Pritam Singh',
#   {'links': {(61, 73): {'Pritam Singh': 1.0}},
#    'entities': [(61, 73, 's_pol')]}),
#  ('Conspiracy theory of the year: RK is a mole planted by PAP to secure their chances for next GE.',
#   {'links': {(55, 58): {"People's Action Party": 1.0}},
#    'entities': [(55, 58, 'ORG')]}),
#  ('I feel sad for Samantha and hopes she knows that many people are sending her strength and love. It’s painful to say but many people talk like Sylvia, be it in front of employees, colleagues or fellow students. It does not have to be a boss and staff scenario. If only more people understand that words can hurt and be careful over words choice. Using vulgarity is more often than not a bad habit and a poor choice that will one day come back to haunt you.',
#   {'links': {(142, 148): {'Sylvia Lim': 1.0}},
#    'entities': [(142, 148, 's_pol')]}),
#  ("Ong Ye Kung is pro reopening though, probably he's being overruled. Sigh",
#   {'links': {(0, 11): {'Ong Ye Kung': 1.0}}, 'entities': [(0, 11, 's_pol')]}),
#  ('COVID-19 diaries: A safe distancing ambassador takes name-calling in her stride - CNA',
#   {'links': {(82, 85): {'CNA': 1.0}}, 'entities': [(82, 85, 'ORG')]}),
#  ("I mean, it's *technically* true, but that disclaimer makes the Noose video look like a CNA segment when the description is hidden.",
#   {'links': {(87, 90): {'CNA': 1.0}}, 'entities': [(87, 90, 'ORG')]}),
#  ('Public transport ridership falls to 60% of pre-pandemic levels; Govt to relook financial impact when Covid-19 stabilises: Iswaran',
#   {'links': {(122, 129): {'S. Iswaran': 1.0}},
#    'entities': [(122, 129, 's_pol')]}),
#  ("> not allow people to sue the PAP fairly?\n\nWhat is stopping you from suing the PAP. Chiam See Tong sued the PAP Minister and MP and won. Maybe if you don't do any wrong you won't lose. Only the clueless thinks the opposition cannot sue the PAP and they cannot win.",
#   {'links': {(240, 243): {"People's Action Party": 1.0}},
#    'entities': [(240, 243, 'ORG')]}),
#  ('COVID-19: For Singapore to re-open, migrant workers must return to work safely, says Gan Kim Yong',
#   {'links': {(85, 97): {'Gan Kim Yong': 1.0}},
#    'entities': [(85, 97, 's_pol')]}),
#  ('ST Editor Tan Ooi Boon: 20 - 40s being brandished as "Peter Pan" for spending on "short term needs such as buying homes, cars and going on holidays". Thoughts?',
#   {'links': {(0, 2): {'The Straits Times': 1.0}},
#    'entities': [(0, 2, 'ORG')]}),
#  ("If I don't agree with them, I'm in the wrong kinda deal.\n\nHonestly, I just don't really care for politics, and I assume many people don't.\n\nI don't need change in the country, I just need the country to not be in shambles. And with the PAP I don't think it will.\n\nBut yeah, it's easy enough to look at someone with a differing mindset and downvote them.",
#   {'links': {(236, 239): {"People's Action Party": 1.0}},
#    'entities': [(236, 239, 'ORG')]}),
#  ('Inter NS friendship. Part 2.',
#   {'links': {(6, 8): {'National Service': 1.0}}, 'entities': [(6, 8, 'ORG')]}),
#  ('27,000 children have had Covid-19 since Omicron wave started: MOH',
#   {'links': {(62, 65): {'Ministry of Health': 1.0}},
#    'entities': [(62, 65, 'ORG')]}),
#  ('Jamus smiles a lot more than Andrew when speaking tho... but yeah the energy is so infectious',
#   {'links': {(0, 5): {'Jamus Lim': 1.0}}, 'entities': [(0, 5, 's_pol')]}),
#  ('For all those WP supporters! Come join the petition',
#   {'links': {(14, 16): {"Workers' Party": 1.0}},
#    'entities': [(14, 16, 'ORG')]}),
#  ('Yeah HSK is kinda like the nerdy awkward kid in class who is otherwise cool with everyone.\n\nJust dunno if he is interested in setting a different tone for the party or not.',
#   {'links': {(5, 8): {'Heng Swee Keat': 1.0}}, 'entities': [(5, 8, 's_pol')]}),
#  ("I'm not sure about MOE's stance but I suspect they'll make a decision if students can choose to stay home if it's difficult for them to return to school after the Hari Raya holiday.",
#   {'links': {(19, 22): {'Ministry of Education': 1.0}},
#    'entities': [(19, 22, 'ORG')]}),
#  ("OYK was probably over-ruled by more risk-averse decision makers. And basically he anyhow talked earlier, with his hypothetical of 25->50->100 ICU cases when we don't even have the appetite to stomach more than say 5 or 10 ICU cases.\n\nHowever, given that he used 1 week as the doubling time (for ICU cases) when we're seeing 1 day as the doubling time for positive cases, I can understand the risk-averse position. But it just irrationally feels like OYK keeps jinxing us!",
#   {'links': {(450, 453): {'Ong Ye Kung': 1.0}},
#    'entities': [(450, 453, 's_pol')]}),
#  ("Coronavirus: MHA investigating religious teacher for 'xenophobic, racist' posts",
#   {'links': {(13, 16): {'Ministry of Home Affairs\xa0': 1.0}},
#    'entities': [(13, 16, 'ORG')]}),
#  ("ST: 5 Weak Links in Singapore's COVID-19 battle",
#   {'links': {(0, 2): {'The Straits Times': 1.0}},
#    'entities': [(0, 2, 'ORG')]}),
#  ('Bro I met before ambitious NS ps leh. So low still want wayang that much is just beyond me',
#   {'links': {(27, 29): {'National Service': 1.0}},
#    'entities': [(27, 29, 'ORG')]}),
#  ('Right well I think most of the people on this sub are nowhere near 30 lol most seem to be people either doing NS or a few years post ORD so the pain is still fresh \n\nOnce you hit late 20s you have so many other shit to worry about right like who will stay up til 4am and think about NS',
#   {'links': {(283, 285): {'National Service': 1.0}},
#    'entities': [(283, 285, 'ORG')]}),
#  ("Nothing to do with the PAP at least for Chinatown.\n\nThe Raffles Town plan that segregated Singapore into ethnic districts didn't really work as enforcement (other than the AMDK area) was lax and people just built where every they wanted. ",
#   {'links': {(23, 26): {"People's Action Party": 1.0}},
#    'entities': [(23, 26, 'ORG')]}),
#  ('Confirm vote PAP.',
#   {'links': {(13, 16): {"People's Action Party": 1.0}},
#    'entities': [(13, 16, 'ORG')]}),
#  ('Plan for GST hike between 2022 and 2025 remains unchanged, all options being considered to address wealth inequality: Lawrence Wong',
#   {'links': {(118, 131): {'Lawrence Wong': 1.0}},
#    'entities': [(118, 131, 's_pol')]}),
#  ("diminish it all you want. \n\nSAFVC is as equivalent to NS as the [Women's boot camp](https://www.straitstimes.com/singapore/1000-women-fall-in-for-ns-boot-camp)",
#   {'links': {(54, 56): {'National Service': 1.0}},
#    'entities': [(54, 56, 'ORG')]}),
#  ('Early Changi Airport COVID-19 cases from zone serving higher-risk countries’ arrivals: Ong Ye Kung',
#   {'links': {(87, 98): {'Ong Ye Kung': 1.0}},
#    'entities': [(87, 98, 's_pol')]}),
#  ('PAP fields replacement candidate Ivana Lim',
#   {'links': {(0, 3): {"People's Action Party": 1.0}},
#    'entities': [(0, 3, 'ORG')]}),
#  ('PM Lee Hsien Loong just got his COVID-19 vaccine today. (Picture taken from Facebook)',
#   {'links': {(3, 18): {'Lee Hsien Loong': 1.0}},
#    'entities': [(3, 18, 's_pol')]}),
#  ("I think he still is! This was posted from MOE's Facebook that credits him as a Lit teacher.",
#   {'links': {(42, 45): {'Ministry of Education': 1.0}},
#    'entities': [(42, 45, 'ORG')]}),
#  ('Because Edwin Tong represents good drama, if not justice. The idiocy now flooding this subreddit. Is but a negligible ponding, compared to the wake of City Harvest trials. That washed over every social media platform locally.',
#   {'links': {(8, 18): {'Edwin Tong': 1.0}}, 'entities': [(8, 18, 's_pol')]}),
# ...
#   {'links': {(11, 14): {"People's Action Party": 1.0}},
#    'entities': [(11, 14, 'ORG')]}),
#  ('No changes to Covid-19 curbs for now but Govt monitoring situation closely: MOH',
#   {'links': {(76, 79): {'Ministry of Health': 1.0}},
#    'entities': [(76, 79, 'ORG')]}),
#  ("here's another stupid question for ya'll: Where can I get that PAP face mask? Looks dope man :)",
#   {'links': {(63, 66): {"People's Action Party": 1.0}},
#    'entities': [(63, 66, 'ORG')]}),
#  ('Couple of years back if they bothered they can corroborate ezlink card tapping time w cctv footage but too tedious alr so they want the easy way which is TT. Disgusting tbh',
#   {'links': {(154, 156): {'Trace Together': 1.0}},
#    'entities': [(154, 156, 'ORG')]}),
#  ('i pray every day will be better then yesterday. And we will overcome the Covid.....tks Mr Sun Rise..',
#   {'links': {(90, 93): {'Sun Xueling': 1.0}},
#    'entities': [(90, 93, 's_pol')]}),
#  ('Op-ed Piece by MP Jamus Lim on Minimum Wage',
#   {'links': {(18, 27): {'Jamus Lim': 1.0}}, 'entities': [(18, 27, 's_pol')]}),
#  ("Nope, because you wouldn't know that the data on TT would prove anything since you wouldn't be able to access it in the first place.\n\nIt's quaint that you can imagine that the TT data can be used as evidence to prove his innocence though, seeing how he can pass his token to someone else while he commits the crime to create a weak alibi",
#   {'links': {(176, 178): {'Trace Together': 1.0}},
#    'entities': [(176, 178, 'ORG')]}),
#  ('Interesting life story from Chan Chun Sing',
#   {'links': {(28, 42): {'Chan Chun Sing': 1.0}},
#    'entities': [(28, 42, 's_pol')]}),
#  ("Not surprised at all. MOH kok up and hospitals under pressure.  \nBut shit this still sucks. Kiss your social lives goodbye.  \nI need to get out of here for a while. Hope my Dec trip doesn't fuck up.",
#   {'links': {(22, 25): {'Ministry of Health': 1.0}},
#    'entities': [(22, 25, 'ORG')]}),
#  ('1. We dont know that. More than 1 report was filed.\n2. The police do not investigate every report. The AGC does not advice on every report. Both are exceptional moves made within 1/2? days of the filing. Is it spevulative that the PAP influenced this? Yes. But is the PAP wholeheartedly supporting the report? Yes, definitely.',
#   {'links': {(268, 271): {"People's Action Party": 1.0}},
#    'entities': [(268, 271, 'ORG')]}),
#  ('provided their WP’s leader continues to back her up since RK always raises issues with “good intentions”',
#   {'links': {(15, 17): {"Workers' Party": 1.0}},
#    'entities': [(15, 17, 'ORG')]}),
#  ("GE2020: PSP will 'respect' WP's Pritam Singh as Leader of the Opposition - Tan Cheng Bock",
#   {'links': {(48, 72): {'Pritam Singh': 1.0}},
#    'entities': [(48, 72, 's_pol')]}),
#  ('it appears that NS is both inconvenient for those doing it and those trying to argue about issues on r/singapore',
#   {'links': {(16, 18): {'National Service': 1.0}},
#    'entities': [(16, 18, 'ORG')]}),
#  ('Has been a few days. Mr Lawrence did not make the comment on “They may not have kept to the rule of five. - we can find out who they are, — we might be able to identify and take them to task” for National Day. Hypocrite caught red handed !',
#   {'links': {(24, 32): {'Lawrence Wong': 1.0}},
#    'entities': [(24, 32, 's_pol')]}),
#  ('When LMW screwed up in Parliament, Vivian swooped in to save him with the lousy school comment  \nNow when MMTF screw up constantly, RK swooped in to save them with this shit',
#   {'links': {(35, 41): {'Vivian Balakrishnan': 1.0}},
#    'entities': [(35, 41, 's_pol')]}),
#  ("Because of the election system right.? The 'First Past The Post' system. This system is really eroding our voice. I am sure many Singaporeans support the oppositions, but PAP usually gets the most (not majority) votes. So. PAP wins. Singapore would definitely benefit from a mixed party electoral or a ranked choice election.",
#   {'links': {(223, 226): {"People's Action Party": 1.0}},
#    'entities': [(223, 226, 'ORG')]}),
#  ('When will I get to know my new NS posting order?',
#   {'links': {(31, 33): {'National Service': 1.0}},
#    'entities': [(31, 33, 'ORG')]}),
#  ('curious if SPH only has sinkies working really. i remembered seeing pinoy names as reporters before.',
#   {'links': {(11, 14): {'The Straits Times': 1.0}},
#    'entities': [(11, 14, 'ORG')]}),
#  ('National Day Parade 2021 to be postponed to Aug 21: MINDEF',
#   {'links': {(52, 58): {'Ministry of Defence ': 1.0}},
#    'entities': [(52, 58, 'ORG')]}),
#  ("Yeah man it's so annoying like we're the assholes who're panic buying masks/food and stuff and like there was literally just an article talking about Singapore gov's efficient handling of the mask distributions and now fb commenters are like why no mask? pap out! Government suck!\n\nLike bruh you can't blame the government when the people are assholes lol",
#   {'links': {(264, 274): {'Government': 1.0}},
#    'entities': [(264, 274, 'ORG')]}),
#  ('The P in Sylvia Chan stands for Professionalism',
#   {'links': {(9, 15): {'Sylvia Lim': 1.0}}, 'entities': [(9, 15, 's_pol')]}),
#  ('ty for sharing. hope all is & will be well with your mom.\n\nthis is not the 1st time I\'ve heard of huge delays or even what can be construed as "stalling". your case is extra worrying since you were PCR positive + ineligible for H.R.\n\nimo take a cue from how OYK and MTF  are extremely intelligent & capable people, yet these "failings" keep happening + their 5000 case/day goal. Can we really believe that our brightest keep getting caught off-guard?',
#   {'links': {(258, 261): {'Ong Ye Kung': 1.0}},
#    'entities': [(258, 261, 's_pol')]}),
#  ('MOH trying to explain what to do when your ART/PCR test is positive.',
#   {'links': {(0, 3): {'Ministry of Health': 1.0}},
#    'entities': [(0, 3, 'ORG')]}),
#  ('[NS detention barracks and job prospects]',
#   {'links': {(1, 3): {'National Service': 1.0}}, 'entities': [(1, 3, 'ORG')]}),
#  ('If the talents knew about Sylvia intention\'s that she wanted to use them to seal the deal for a free delivery for exchange of sexual favours. I\'m sure they would not even attend the "fun night out". She basically exploited one of the talent when she was at her lowest point? It\'s still really scummy and inhumane for Sylvia to do that.',
#   {'links': {(317, 323): {'Sylvia Lim': 1.0}},
#    'entities': [(317, 323, 's_pol')]}),
#  ("Why I'm glad that the Workers Party is still the only Opposition in government (no I'm not anti-TCB or any other Opposition)",
#   {'links': {(113, 123): {'Opposition': 1.0}},
#    'entities': [(113, 123, 'ORG')]}),
#  ('Just wanted to chime in. Thanks for sharing! I literally just resigned from MOE like half an hour ago. I don’t really know what’s next, but I’m glad I’m free. And already much happier.',
#   {'links': {(76, 79): {'Ministry of Education': 1.0}},
#    'entities': [(76, 79, 'ORG')]}),
#  ('Well, to be fair, K Shan is rather antagonistic. I wouldn’t like him very much either.',
#   {'links': {(20, 24): {'K Shanmugam': 1.0}},
#    'entities': [(20, 24, 's_pol')]}),
#  ('That means you not close enough. Back when I was in NS, the sentries taxed the hell out of my bak kwa when I booked in. When I told him \n\n"Bang, this is pork sial lah"\n\n"Bro, why you tell me?"\n\n😑',
#   {'links': {(52, 54): {'National Service': 1.0}},
#    'entities': [(52, 54, 'ORG')]}),
#  ('Sorry for misunderstanding you. I agree with you that we should be discerning with our vote and I will not always vote for PAP, once there is better party (sadly none at this point), I will definitely switch my vote.\n\nI am just pissed some people are just vote for the sake of opposing, I know a friend that vote RDP in Sembawang GRC without even knowing a single member there just for the sake of not having one party rule. Imagine substantial segment of population think tjis way..',
#   {'links': {(123, 126): {"People's Action Party": 1.0}},
#    'entities': [(123, 126, 'ORG')]}),
#  ('I wonder if the WP is a coalition of Teochew supporters + young liberal people',
#   {'links': {(16, 18): {"Workers' Party": 1.0}},
#    'entities': [(16, 18, 'ORG')]}),
#  ("Conflicting accounts in Raeesah Khan saga open 'can of worms'; Workers' Party must limit damage, say analysts",
#   {'links': {(63, 77): {"Workers' Party": 1.0}},
#    'entities': [(63, 77, 'ORG')]}),
#  ('I ticked the checkbox that said "I do not wish to serve as an officer / specialist". I served my 2 years+ of NS as a enlistee and aside from a few power tripping commanders, I generally had a good time in the army just messing around with my fellow enlistees and a few of the more down to earth specialists. I was a tank operator so it wasn\'t because I was in some admin role.\n\nWhat you said made me glad I didn\'t have to witness or experience what you did.',
#   {'links': {(109, 111): {'National Service': 1.0}},
#    'entities': [(109, 111, 'ORG')]}),
#  ('Too much time spent attacking PAP and not answering the questions.',
#   {'links': {(30, 33): {"People's Action Party": 1.0}},
#    'entities': [(30, 33, 'ORG')]}),
#  ('Coverage was by Reuters, not ST.',
#   {'links': {(29, 31): {'The Straits Times': 1.0}},
#    'entities': [(29, 31, 'ORG')]}),
#  ('Experts question relevance of SafeEntry, TraceTogether amid endemic Covid-19',
#   {'links': {(41, 54): {'Trace Together': 1.0}},
#    'entities': [(41, 54, 'ORG')]}),
#  ('Louis Ng: Allow cats to be kept in HDB flats',
#   {'links': {(0, 8): {'Louis Ng': 1.0}}, 'entities': [(0, 8, 's_pol')]}),
#  ("MOH doing more to curb popularity of vaping among the young, will study NZ's cohort ban on smoking",
#   {'links': {(0, 3): {'Ministry of Health': 1.0}},
#    'entities': [(0, 3, 'ORG')]}),
#  ('Tharman Shanmugaratnam',
#   {'links': {(0, 22): {'Tharman Shanmugaratnam': 1.0}},
#    'entities': [(0, 22, 's_pol')]}),
#  ('PSP Leong Mun Wai speaks Japanese. SENPAI',
#   {'links': {(4, 17): {'Leong Mun Wai': 1.0}},
#    'entities': [(4, 17, 's_pol')]}),
#  ('She does not need to forge it. This woman is a proven liar, and more than once unreliable as a witness. She could simply be typing shit to intentionally mislead her staff.\n\nAgain, I am speculating this is something the WP leadership is\\* probably thinking at the moment. She could be telling the truth of course.',
#   {'links': {(219, 221): {"Workers' Party": 1.0}},
#    'entities': [(219, 221, 'ORG')]}),
#  ('Singapore offers A330 tanker aircraft to help US airlift evacuees from Afghanistan: PM Lee',
#   {'links': {(84, 90): {'Lee Hsien Loong': 1.0}},
#    'entities': [(84, 90, 's_pol')]}),
#  ('Two private firms to operate 30 SCDF ambulances as part of new Government-contractor model',
#   {'links': {(63, 73): {'Government': 1.0}}, 'entities': [(63, 73, 'ORG')]}),
#  ("I'm gonna wager that she'll step down within a couple of days. She's now a liability for WP. Keeping her won't do them much good.",
#   {'links': {(89, 91): {"Workers' Party": 1.0}},
#    'entities': [(89, 91, 'ORG')]}),
#  ('Teen detained for planning mosque attacks: Rise of right-wing extremism in Singapore worrying, says Shanmugam',
#   {'links': {(100, 109): {'K Shanmugam': 1.0}},
#    'entities': [(100, 109, 's_pol')]}),
#  ("If you don't get Covid-19 vaccine, get ready for more frequent testing &amp; quarantine: Lawrence Wong",
#   {'links': {(89, 102): {'Lawrence Wong': 1.0}},
#    'entities': [(89, 102, 's_pol')]}),
#  ("TCH didn't talk like he was still in the army giving command to troops when he made his debut speech. This joke has nothing to do with sexism. It was targeted at the way she spoke during nomination day. You can go look up that speech. Other former generals like CCS and TCJ didn't get this kind of treatment because they managed to switch to civi mode. CCS on the other hand still had that ki chew think hanging on him.",
#   {'links': {(353, 356): {'Chan Chun Sing': 1.0}},
#    'entities': [(353, 356, 's_pol')]}),
#  ('CNA-promoted news site disappears; new site propped by SMRT Feedback - The Online Citizen',
#   {'links': {(0, 3): {'CNA': 1.0}}, 'entities': [(0, 3, 'ORG')]}),
#  ('NS Checkup advice for people who are going to do it in the future. (NS checkup/CMPB Checkup/NS medical)',
#   {'links': {(92, 94): {'National Service': 1.0}},
#    'entities': [(92, 94, 'ORG')]}),
#  ('The small QR code on the TraceTogether paper says “Love and peace!”',
#   {'links': {(25, 38): {'Trace Together': 1.0}},
#    'entities': [(25, 38, 'ORG')]}),
#  ('Maybe this is the ultimate 4D chess move LMW learnt from RI',
#   {'links': {(41, 44): {'Leong Mun Wai': 1.0}},
#    'entities': [(41, 44, 's_pol')]}),
#  ('This is probably more to do with NS than Singlish.\n\nOwn time own target was pretty much heard by a lot of male Singaporeans',
#   {'links': {(33, 35): {'National Service': 1.0}},
#    'entities': [(33, 35, 'ORG')]}),
#  ("Genuinely happy for you that you are now clear of cancer! We often take life for granted until such dire situations. I'm glad you have emerged stronger.\n\nJust curious, when was your last time in camp? Was it right before the block leave to celebrate Christmas/New Year? Also, what was the process like when MINDEF reduce your PES status to F and when were officially discharged? Did you have to return to camp, receive house visits etc?",
#   {'links': {(307, 313): {'Ministry of Defence ': 1.0}},
#    'entities': [(307, 313, 'ORG')]}),
#  ("Yes, at least helping out with polling made me confident that the polling process itself is fair. What happens in the political landscape outside of polling day though... That's another story lol.\n\nI did see a lot of elderly who thought that if they didn't vote for PAP they wouldn't get subsidies in future.",
#   {'links': {(266, 269): {"People's Action Party": 1.0}},
#    'entities': [(266, 269, 'ORG')]}),
#  ('Really khan nee nah... Bet WP regrets fielding her',
#   {'links': {(27, 29): {"Workers' Party": 1.0}},
#    'entities': [(27, 29, 'ORG')]}),
#  ('STB says it has no plans to change redemption method of SingapoRediscovers vouchers - CNA',
#   {'links': {(86, 89): {'CNA': 1.0}}, 'entities': [(86, 89, 'ORG')]}),
#  ('Vivian must\'ve been thinking "I should\'ve gone to RI!"\n\n/s',
#   {'links': {(0, 6): {'Vivian Balakrishnan': 1.0}},
#    'entities': [(0, 6, 's_pol')]}),
#  ('Because his retirement is secure with the funds he procured from cushy jobs as a result of being LKY’s son, and he does actually benefit from stepping up - he has a personal grievance against LHL and for some people, redressing personal grievances is as big a benefit as they come. It certainly matters a lot to LHY, anyone with half a brain can see that.\n\nIt’s harder to run because then he has to do the work. He doesn’t want to, and he doesn’t need the money. That’s obvious.',
#   {'links': {(192, 195): {'Lee Hsien Loong': 1.0}},
#    'entities': [(192, 195, 's_pol')]}),
#  ("Guess who gets to define what a falsehood is?\n\nIt's the fucking PAP. Like always.",
#   {'links': {(64, 67): {"People's Action Party": 1.0}},
#    'entities': [(64, 67, 'ORG')]}),
#  ('Small empty space - Josephine approves',
#   {'links': {(20, 29): {'Josephine Teo': 1.0}},
#    'entities': [(20, 29, 's_pol')]}),
#  ('Police say no offence committed by PAP, after reports lodged against party for statement on Raeesah Khan',
#   {'links': {(92, 104): {'Raeesah Khan': 1.0}},
#    'entities': [(92, 104, 's_pol')]}),
#  ('Security Trooper in NS',
#   {'links': {(20, 22): {'National Service': 1.0}},
#    'entities': [(20, 22, 'ORG')]}),
#  ('Any way to help this guy? (Claims SPH is torturing him; likely psychosis)',
#   {'links': {(34, 37): {'The Straits Times': 1.0}},
#    'entities': [(34, 37, 'ORG')]}),
#  ('You can show proof via healthhub app or paper doc, but the simplest way is for the venue to scan you using your TT token',
#   {'links': {(112, 114): {'Trace Together': 1.0}},
#    'entities': [(112, 114, 'ORG')]}),
#  ('Did ST feature a gay couple in a happy, normal setting?',
#   {'links': {(4, 6): {'The Straits Times': 1.0}},
#    'entities': [(4, 6, 'ORG')]}),
#  ('Nonsense la Jamus',
#   {'links': {(12, 17): {'Jamus Lim': 1.0}}, 'entities': [(12, 17, 's_pol')]}),
#  ...]

# %%
#converting data into Spacy training example format
TRAIN_EXAMPLES = []
for text, annotation in tqdm(train_data):
    example = Example.from_dict(nlp.make_doc(text), annotation)
    example.reference = nlp(example.reference)
    TRAIN_EXAMPLES.append(example)
# Out:
# 100%|██████████| 9956/9956 [05:59<00:00, 27.73it/s]

# %%
from spacy.ml.models import load_kb

# %%
entity_linker = nlp.add_pipe("entity_linker", config={"incl_prior": False}, last=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5092/3725283774.py in <module>
# ----> 1 entity_linker = nlp.add_pipe("entity_linker", config={"incl_prior": False}, last=True)
#       2
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     774         name = name if name is not None else factory_name
#     775         if name in self.component_names:
# --> 776             raise ValueError(Errors.E007.format(name=name, opts=self.component_names))
#     777         if source is not None:
#     778             # We're loading the component from a model. After loading the
#
# ValueError: [E007] 'entity_linker' already exists in pipeline. Existing names: ['transformer', 'tagger', 'parser', 'attribute_ruler', 'ner', 'entity_linker']

# %%
entity_linker.initialize(get_examples=lambda: TRAIN_EXAMPLES, kb_loader=load_kb('../assets/mp_kb'))

# %%
import random
from spacy.util import minibatch, compounding

# %%
from tqdm import tqdm

# %%
# %%time

with nlp.select_pipes(enable=["entity_linker"]):
    optimizer = nlp.resume_training()
    for itn in tqdm(range(200)):
        random.shuffle(TRAIN_EXAMPLES)
        batches = minibatch(TRAIN_EXAMPLES, size=compounding(256,528, 1.001))  # increasing batch sizes
        losses = {}
        for batch in batches:
            nlp.update(batch,
                       drop=0.1,      # prevent overfitting with dropout
                       losses=losses,
                       sgd=optimizer)
        if itn % 50 == 0:
            print(itn, "Losses", losses)   # print the training loss
print(itn, "Losses", losses)
# Out:
#   0%|          | 1/200 [00:46<2:33:17, 46.22s/it]
# 0 Losses {'entity_linker': 39.49820387363434}
#  26%|██▌       | 51/200 [35:34<2:03:53, 49.89s/it]
# 50 Losses {'entity_linker': 39.40390223264694}
#  50%|█████     | 101/200 [1:10:03<1:02:41, 38.00s/it]
# 100 Losses {'entity_linker': 39.46898150444031}
#  76%|███████▌  | 151/200 [1:42:25<35:01, 42.90s/it]
# 150 Losses {'entity_linker': 39.43627601861954}
# 100%|██████████| 200/200 [2:11:50<00:00, 39.55s/it]
# 199 Losses {'entity_linker': 39.45754611492157}
# Wall time: 2h 11min 50s

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40648/2161595591.py in <module>
# ----> 1 source = spacy.load('en_core_web_trf')
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\__init__.py in load(name, vocab, disable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, exclude, config)
#     418             return get_lang_class(name.replace("blank:", ""))()
#     419         if is_package(name):  # installed as package
# --> 420             return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     421         if Path(name).exists():  # path to model data directory
#     422             return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\util.py in load_model_from_package(name, vocab, disable, exclude, config)
#     451     """
#     452     cls = importlib.import_module(name)
# --> 453     return cls.load(vocab=vocab, disable=disable, exclude=exclude, config=config)  # type: ignore[attr-defined]
#     454
#     455
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\en_core_web_trf\__init__.py in load(**overrides)
#       8
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\util.py in load_model_from_init_py(init_file, vocab, disable, exclude, config)
#     613     if not model_path.exists():
#     614         raise IOError(Errors.E052.format(path=data_path))
# --> 615     return load_model_from_path(
#     616         data_path,
#     617         vocab=vocab,
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\util.py in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     487     config = load_config(config_path, overrides=overrides)
#     488     nlp = load_model_from_config(config, vocab=vocab, disable=disable, exclude=exclude)
# --> 489     return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#     490
#     491
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\language.py in from_disk(self, path, exclude, overrides)
#    2040             # Convert to list here in case exclude is (default) tuple
#    2041             exclude = list(exclude) + ["vocab"]
# -> 2042         util.from_disk(path, deserializers, exclude)  # type: ignore[arg-type]
#    2043         self._path = path  # type: ignore[assignment]
#    2044         self._link_components()
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\util.py in from_disk(path, readers, exclude)
#    1297         # Split to support file names like meta.json
#    1298         if key.split(".")[0] not in exclude:
# -> 1299             reader(path / key)
#    1300     return path
#    1301
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\language.py in <lambda>(p, proc)
#    2034             if not hasattr(proc, "from_disk"):
#    2035                 continue
# -> 2036             deserializers[name] = lambda p, proc=proc: proc.from_disk(  # type: ignore[misc]
#    2037                 p, exclude=["vocab"]
#    2038             )
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy_transformers\pipeline_component.py in from_disk(self, path, exclude)
#     418             "model": load_model,
#     419         }
# --> 420         util.from_disk(path, deserialize, exclude)
#     421         return self
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy\util.py in from_disk(path, readers, exclude)
#    1297         # Split to support file names like meta.json
#    1298         if key.split(".")[0] not in exclude:
# -> 1299             reader(path / key)
#    1300     return path
#    1301
#
# E:\anaconda3\envs\spacyenv\lib\site-packages\spacy_transformers\pipeline_component.py in load_model(p)
#     392             try:
#     393                 with open(p, "rb") as mfile:
# --> 394                     self.model.from_bytes(mfile.read())
#     395             except AttributeError:
#     396                 raise ValueError(Errors.E149) from None
#
# KeyboardInterrupt:

# %%
# Evaluating

# %%
VAL_EXAMPLES = []
for text, annotation in val_data:
    example = Example.from_dict(nlp.make_doc(text), annotation)
    example.predicted = nlp(example.predicted)
    #print(example.reference)
    VAL_EXAMPLES.append(example)

# %%
scorer = Scorer(nlp)

# %%
scores = scorer.score(VAL_EXAMPLES)

# %%
scores
# Out:
# {'token_acc': 1.0,
#  'token_p': 1.0,
#  'token_r': 1.0,
#  'token_f': 1.0,
#  'tag_acc': None,
#  'sents_p': None,
#  'sents_r': None,
#  'sents_f': None,
#  'dep_uas': None,
#  'dep_las': None,
#  'dep_las_per_type': None,
#  'pos_acc': None,
#  'morph_acc': None,
#  'morph_micro_p': None,
#  'morph_micro_r': None,
#  'morph_micro_f': None,
#  'morph_per_feat': None,
#  'lemma_acc': None,
#  'ents_p': 0.5030814142069413,
#  'ents_r': 0.6519546027742749,
#  'ents_f': 0.5679238374221897,
#  'ents_per_type': {'ORG': {'p': 0.7853164556962026,
#    'r': 0.9961464354527938,
#    'f': 0.8782559456398642},
#   'PERSON': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#   's_pol': {'p': 0.0, 'r': 0.0, 'f': 0.0}},
#  'nel_score': 0.9892148403796377,
#  'nel_score_desc': 'micro F',
#  'nel_micro_p': 1.0,
#  'nel_micro_r': 0.9786598378147674,
#  'nel_micro_f': 0.9892148403796377,
#  'nel_macro_p': 1.0,
#  'nel_macro_r': 0.9684343434343434,
#  'nel_macro_f': 0.983702737940026,
#  'nel_f_per_type': {'ORG': {'p': 1.0, 'r': 1.0, 'f': 1.0},
#   's_pol': {'p': 1.0, 'r': 0.9368686868686869, 'f': 0.9674054758800521}}}

# %%
nlp.to_disk('../model')
